# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./movies-data/combine_data.csv")
df.head()
# Out:
#    Unnamed: 0  adult belongs_to_collection    budget  \
# 0           0  False                   NaN  60000000
# 1           1  False                   NaN  60000000
# 2           2  False                   NaN  60000000
# 3           3  False                   NaN  60000000
# 4           4  False                   NaN  60000000
#
#                                               genres homepage   id    imdb_id  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN  949  tt0113277
# 1  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN  949  tt0113277
# 2  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN  949  tt0113277
# 3  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN  949  tt0113277
# 4  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...      NaN  949  tt0113277
#
#   original_language original_title  ... title  video vote_average vote_count  \
# 0                en           Heat  ...  Heat  False          7.7     1886.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46625 entries, 0 to 46624
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             46625 non-null  int64
#  1   Unnamed: 0.1           46625 non-null  int64
#  2   belongs_to_collection  46625 non-null  int64
#  3   budget                 9053 non-null   float64
#  4   genres                 46625 non-null  object
#  5   id                     46625 non-null  int64
#  6   original_language      46625 non-null  object
#  7   popularity             46625 non-null  float64
#  8   production_companies   46625 non-null  object
#  9   production_countries   46625 non-null  object
#  10  release_date           46625 non-null  object
#  11  revenue                7537 non-null   float64
#  12  runtime                46625 non-null  float64
#  13  status                 46625 non-null  object
# ...

# %%
df = df.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1)

# %%
df.describe()
# Out:
#        belongs_to_collection        budget             id    popularity  \
# count           46625.000000  9.053000e+03   46625.000000  46625.000000
# mean                0.098080  5.643434e-02  109679.400601      2.894354
# std                 0.297427  8.987609e-02  112916.080257      5.950432
# min                 0.000000  2.631579e-09       2.000000      0.000000
# 25%                 0.000000  5.263158e-03   26758.000000      0.382681
# 50%                 0.000000  2.105263e-02   61294.000000      1.114882
# 75%                 0.000000  6.578948e-02  159622.000000      3.610412
# max                 1.000000  1.000000e+00  469172.000000    547.488300
#
#             revenue       runtime  vote_average    vote_count       profit  \
# count  7.537000e+03  46625.000000  46625.000000  46625.000000  5458.000000
# mean   1.795189e-01     94.084856      5.611608    108.167399     0.154834
# std    3.839304e-01     38.347053      1.932311    486.424355     0.366439
# ...

# %%
df.isna().any()
# Out:
# belongs_to_collection    False
# budget                    True
# genres                   False
# id                       False
# original_language        False
# popularity               False
# production_companies     False
# production_countries     False
# release_date             False
# revenue                   True
# runtime                  False
# status                   False
# title                    False
# vote_average             False
# vote_count               False
# cast                     False
# crew                     False
# keywords                 False
# release_year             False
# profit                    True
# weighted_rating          False
# dtype: bool

# %%
df.isna().sum()
# Out:
# belongs_to_collection        0
# budget                   37572
# genres                       0
# id                           0
# original_language            0
# popularity                   0
# production_companies         0
# production_countries         0
# release_date                 0
# revenue                  39088
# runtime                      0
# status                       0
# title                        0
# vote_average                 0
# vote_count                   0
# cast                         0
# crew                         0
# keywords                     0
# release_year                 0
# profit                   41167
# weighted_rating              0
# dtype: int64

# %%
numerical_data = ['belongs_to_collection','budget', 'id', 'popularity', 'revenue', 'runtime',
                    'vote_average', 'vote_count', 'profit', 'weighted_rating']
categorical_data = ['original_language', 'release_date', 'release_year', 'status', 'title']
list_data = ['genres', 'production_countries', 'production_companies']
df[numerical_data].hist(bins= 50, figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'belongs_to_collection'}>,
#         <AxesSubplot:title={'center':'budget'}>,
#         <AxesSubplot:title={'center':'id'}>],
#        [<AxesSubplot:title={'center':'popularity'}>,
#         <AxesSubplot:title={'center':'revenue'}>,
#         <AxesSubplot:title={'center':'runtime'}>],
#        [<AxesSubplot:title={'center':'vote_average'}>,
#         <AxesSubplot:title={'center':'vote_count'}>,
#         <AxesSubplot:title={'center':'profit'}>],
#        [<AxesSubplot:title={'center':'weighted_rating'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
for col in numerical_data:
    sns.distplot(df[col], kde=True)
    plt.show()
# Out:
# /home/ai/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/ai/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for col in numerical_data:
    sns.boxplot(x=df[col])
    plt.show()

# %%
for col in categorical_data:
    print('-'*50)
    print(f'The column name is: {col}')
    print(df[col].value_counts())
# Out:
# --------------------------------------------------
# The column name is: original_language
# en    32934
# fr     2524
# it     1565
# ja     1419
# de     1111
#       ...
# la        1
# fy        1
# rw        1
# tg        1
# si        1
# Name: original_language, Length: 90, dtype: int64
# --------------------------------------------------
# The column name is: release_date
# 2008-01-01 00:00:00    138
# 2007-01-01 00:00:00    124
# 2009-01-01 00:00:00    123
# 2005-01-01 00:00:00    116
# 2006-01-01 00:00:00    102
#                       ...
# 1957-09-26 00:00:00      1
# 1938-11-21 00:00:00      1
# 1936-08-19 00:00:00      1
# 2010-01-27 00:00:00      1
# 1917-10-21 00:00:00      1
# Name: release_date, Length: 17334, dtype: int64
# --------------------------------------------------
# The column name is: release_year
# 2014.0    2057
# 2015.0    2046
# 2013.0    1953
# 2012.0    1786
# 2011.0    1722
#           ...
# 2020.0       1
# 1887.0       1
# 1878.0       1
# ...

# %%
for label in categorical_data:
    if(label is not 'release_date'):
       sns.barplot(x= df[label].value_counts()[:10].index,
           y= df[label].value_counts()[:10].values)
       plt.xlabel(label)
       plt.xticks(rotation=60)
       plt.ylabel("Frequency")
       plt.title('Show of {} Bar Plot'.format(label))
       plt.show()
# Out:
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /tmp/ipykernel_59673/2905413791.py:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if(label is not 'release_date'):

# %%
df['release_year'].value_counts()[:100].index
# Out:
# Index(['2014.0', '2015.0', '2013.0', '2012.0', '2011.0', '2016.0', '2009.0',
#        '2010.0', '2008.0', '2007.0', '2006.0', '2005.0', '2004.0', '2002.0',
#        '2001.0', '2003.0', '2000.0', '1999.0', '1998.0', '1997.0', '1996.0',
#        '1995.0', '1994.0', '2017.0', '1993.0', '1988.0', '1987.0', '1992.0',
#        '1989.0', '1991.0', '1990.0', '1986.0', '1971.0', '1972.0', '1980.0',
#        '1985.0', '1981.0', '1982.0', '1983.0', '1973.0', '1984.0', '1970.0',
#        '1974.0', '1968.0', '1977.0', '1979.0', '1975.0', '1976.0', '1978.0',
#        '1966.0', '1969.0', '1967.0', '1964.0', '1965.0', '1957.0', '1963.0',
#        '1962.0', '1959.0', '1960.0', '1956.0', '1958.0', '1955.0', '1953.0',
#        '1961.0', '1952.0', '1951.0', '1954.0', '1950.0', '1949.0', '1948.0',
#        '1947.0', '1937.0', '1940.0', '1943.0', '1936.0', '1933.0', '1945.0',
#        '1941.0', '1935.0', '1942.0', '1932.0', '1944.0', '1934.0', '1939.0',
# ...

# %%
sns.barplot(x= df['release_year'].value_counts()[:10].index,
           y= df['release_year'].value_counts()[:10].values)

plt.xlabel('Release_year')
plt.ylabel('Frequency')
plt.title('Show of Release Year Bar Plot')
plt.show()
